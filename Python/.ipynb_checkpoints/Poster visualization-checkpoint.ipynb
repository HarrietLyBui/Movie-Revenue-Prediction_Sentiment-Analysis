# %%
import pandas as pd
import numpy as np
import scipy.special
from bokeh.io import show, output_notebook, curdoc #curdoc give the current document

from bokeh.layouts import gridplot
from bokeh.plotting import figure, show, output_file
output_notebook()

data  = pd.read_csv('C:\\Users\\buihu\\Documents\\2017_2018 Umass Amherst\\Intro to NLP\\Final project\\Git_Repo\\Movie-Revenue-Prediction_Sentiment-Analysis\\Data\\CSV_file\\Final_Dataset.csv')
data.head()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5fdab696-e5fe-471d-99bd-49b500411c0b">Loading BokehJS ...</span>
#     </div>
#    Unnamed: 0   revenue  Adult          Genre ID  IMDB ID  \
# 0           0  27200000  False   [18, 36, 10752]      826
# 1           1   4000000  False  [18, 28, 53, 80]    12628
# 2           2  57400547  False          [28, 12]     9103
# 3           3    191125  False              [18]    25598
# 4           4  80197993  False       [35, 10751]     9353
#
#                           Movie  Popularity Release date original language  \
# 0  The Bridge on the River Kwai   10.156675    10/2/1957                en
# 1                   Playing God    3.426904   10/17/1997                en
# 2                     The Quest    5.646706    4/19/1996                en
# 3             The Indian Runner    1.851309    5/19/1991                en
# ...

# %%
data.columns
# Out:
# Index([u'Unnamed: 0', u' revenue', u'Adult', u'Genre ID', u'IMDB ID', u'Movie',
#        u'Popularity', u'Release date', u'original language', u'run budget',
#        u'run time', u'vote average', u'vote_count', u'sentiment_score'],
#       dtype='object')

# %%
p1 = figure(title="Sentiment Score Distribution from Vader ",tools="save",
            background_fill_color="#E8DDCB")

hist, edges = np.histogram(data['sentiment_score'], density=True, bins=20)
p1.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")

show(p1)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7092cce6-244f-42c0-913e-acc1e0618c69"></div>
# </div>

# %%
plot2 = figure(title = "Sentiment Score vs Revenue", tools="save")

plot2.circle(x=data['sentiment_score'], y=data[' revenue'], line_width = 5, color = "crimson")
show(plot2)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="bb6d8e95-e2da-45aa-a3a4-d89c47f74397"></div>
# </div>

# %%
data_old = pd.read_csv('C:\\Users\\buihu\\Documents\\2017_2018 Umass Amherst\\Intro to NLP\\Final project\\Data\\FinalDataIntegral.csv'
                    )
data_old.head()
# Out:
#    Unnamed: 0  imdbRating  Year  imdbVotes  tomatoMeter  tomatoRating  \
# 0           0         8.0  2002     546828           96           7.9
# 1           1         5.3  2004       5975           12           4.2
# 2           2         5.5  2006      46682           23           4.2
# 3           3         7.9  2002     418339           83           7.0
# 4           4         6.4  2012     119222           27           4.3
#
#    tomatoUserRating  tomatoFresh  tomatoRotten  tomatoUserReviews  \
# 0               3.6          187             8             746403
# 1               2.8           16           116              10000
# 2               3.0           28            93             305893
# 3               3.9          154            31             964203
# 4               3.6           19            52              98086
#
#    tomatoUserMeter  tomatoReviews  sentiment_polarity    revenue   budgets  \
# ...

# %%
plot3 = figure(title = "Sentiment Score vs Revenue", tools="save")

plot3.circle(x=data_old['sentiment_polarity'], y=data_old['revenue'], line_width = 5, color = "crimson")

plot3.xaxis.axis_label = "Sentiment score"
plot3.yaxis.axis_label = "Revenue ($)"
show(plot3)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a46a74cd-b99d-4555-a9c8-9939007ddf03"></div>
# </div>

# %% [markdown]
# **Accuracy for subtraction vs comparison and assignment methods**

# %%
from bokeh.io import show, output_file
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.plotting import figure
from bokeh.transform import factor_cmap


data_set = ['Train Postive', 'Train Negative', 'Test Postive', 'Test Negative']
method = ['Subtraction', 'Comparison & Assignment']

data = {'data_set' : data_set,
        '2015'   : [2, 1, 4, 3, 2, 4],
        '2016'   : [5, 3, 3, 2, 4, 6],
        '2017'   : [3, 2, 4, 4, 5, 3]}

palette = ["#c9d9d3", "#718dbf", "#e84d60"]

# this creates [ ("Apples", "2015"), ("Apples", "2016"), ("Apples", "2017"), ("Pears", "2015), ... ]
x = [ (fruit, year) for fruit in fruits for year in years ]
counts = sum(zip(data['2015'], data['2016'], data['2017']), ()) # like an hstack

source = ColumnDataSource(data=dict(x=x, counts=counts))

p = figure(x_range=FactorRange(*x), plot_height=350, title="Fruit Counts by Year",
           toolbar_location=None, tools="")

p.vbar(x='x', top='counts', width=0.9, source=source, line_color="white",
       fill_color=factor_cmap('x', palette=palette, factors=years, start=1, end=2))

p.y_range.start = 0
p.x_range.range_padding = 0.1
p.xaxis.major_label_orientation = 1
p.xgrid.grid_line_color = None

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="e0169ade-57df-45a4-adf4-6e342fc90e1e"></div>
# </div>
